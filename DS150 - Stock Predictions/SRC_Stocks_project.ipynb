# %%
pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB 119.8 kB/s eta 0:00:26
#      ---------------------------------------- 0.0/3.0 MB 119.8 kB/s eta 0:00:26
#      ---------------------------------------- 0.0/3.0 MB 119.8 kB/s eta 0:00:26
#      ---------------------------------------- 0.0/3.0 MB 119.8 kB/s eta 0:00:26
#      ---------------------------------------- 0.0/3.0 MB 119.8 kB/s eta 0:00:26
# ...

# %%
tesla = yf.Ticker("TSLA")

# Get today's date in the required format (YYYY-MM-DD)
end_date = datetime.today().strftime('2025-02-18')

# Get historical market data from January 1, 2016, to today
tesla_data = tesla.history(start="2016-01-01", end=end_date)

# Display the data
print(tesla_data)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2016-01-04 00:00:00-05:00   15.381333   15.425333   14.600000   14.894000
# 2016-01-05 00:00:00-05:00   15.090667   15.126000   14.666667   14.895333
# 2016-01-06 00:00:00-05:00   14.666667   14.670000   14.398667   14.602667
# 2016-01-07 00:00:00-05:00   14.279333   14.562667   14.244667   14.376667
# 2016-01-08 00:00:00-05:00   14.524000   14.696000   14.051333   14.066667
# ...                               ...         ...         ...         ...
# 2025-02-10 00:00:00-05:00  356.209991  362.700012  350.510010  350.730011
# 2025-02-11 00:00:00-05:00  345.799988  349.369995  325.100006  328.500000
# 2025-02-12 00:00:00-05:00  329.940002  346.399994  329.119995  336.510010
# 2025-02-13 00:00:00-05:00  345.000000  358.690002  342.850006  355.940002
# 2025-02-14 00:00:00-05:00  360.619995  362.000000  347.500000  355.839996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
gamestop = yf.Ticker("GME")

# Get today's date in the required format (YYYY-MM-DD)
end_date = datetime.today().strftime('2025-02-18')

# Get historical market data from January 1, 2016, to today
gme_data = gamestop.history(start="2016-01-01", end=end_date)

# Display the data
print(gme_data)
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2016-01-04 00:00:00-05:00   5.217164   5.491141   5.211375   5.462200
# 2016-01-05 00:00:00-05:00   5.516224   5.597260   5.413964   5.550953
# 2016-01-06 00:00:00-05:00   5.446765   5.545165   5.294340   5.473777
# 2016-01-07 00:00:00-05:00   5.425542   5.550954   5.352223   5.489213
# 2016-01-08 00:00:00-05:00   5.537448   5.554813   5.410106   5.473777
# ...                              ...        ...        ...        ...
# 2025-02-10 00:00:00-05:00  25.500000  27.270000  25.299999  27.120001
# 2025-02-11 00:00:00-05:00  26.850000  27.760000  26.469999  26.559999
# 2025-02-12 00:00:00-05:00  26.120001  26.400000  25.600000  25.990000
# 2025-02-13 00:00:00-05:00  25.750000  26.400000  25.750000  26.340000
# 2025-02-14 00:00:00-05:00  28.900000  28.969999  26.900000  27.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
amd = yf.Ticker("AMD")

# Get today's date in the required format (YYYY-MM-DD)
end_date = datetime.today().strftime('2025-02-18')

# Get historical market data from January 1, 2016, to today
amd_data = amd.history(start="2016-01-01", end=end_date)

# Display the data
print(amd_data)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2016-01-04 00:00:00-05:00    2.770000    2.820000    2.630000    2.770000
# 2016-01-05 00:00:00-05:00    2.770000    2.800000    2.640000    2.750000
# 2016-01-06 00:00:00-05:00    2.660000    2.710000    2.470000    2.510000
# 2016-01-07 00:00:00-05:00    2.430000    2.480000    2.260000    2.280000
# 2016-01-08 00:00:00-05:00    2.360000    2.420000    2.100000    2.140000
# ...                               ...         ...         ...         ...
# 2025-02-10 00:00:00-05:00  108.440002  111.400002  108.150002  110.480003
# 2025-02-11 00:00:00-05:00  108.980003  113.070000  108.940002  111.099998
# 2025-02-12 00:00:00-05:00  109.519997  111.839996  109.059998  111.720001
# 2025-02-13 00:00:00-05:00  112.000000  114.599998  110.400002  111.809998
# 2025-02-14 00:00:00-05:00  112.650002  114.629997  111.699997  113.099998
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
apple = yf.Ticker("AAPL")

# Get today's date in the required format (YYYY-MM-DD)
end_date = datetime.today().strftime('2025-02-18')

# Get historical market data from January 1, 2016, to today
apple_data = apple.history(start="2016-01-01", end=end_date)

# Display the data
print(tesla_data)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2016-01-04 00:00:00-05:00   15.381333   15.425333   14.600000   14.894000
# 2016-01-05 00:00:00-05:00   15.090667   15.126000   14.666667   14.895333
# 2016-01-06 00:00:00-05:00   14.666667   14.670000   14.398667   14.602667
# 2016-01-07 00:00:00-05:00   14.279333   14.562667   14.244667   14.376667
# 2016-01-08 00:00:00-05:00   14.524000   14.696000   14.051333   14.066667
# ...                               ...         ...         ...         ...
# 2025-02-10 00:00:00-05:00  356.209991  362.700012  350.510010  350.730011
# 2025-02-11 00:00:00-05:00  345.799988  349.369995  325.100006  328.500000
# 2025-02-12 00:00:00-05:00  329.940002  346.399994  329.119995  336.510010
# 2025-02-13 00:00:00-05:00  345.000000  358.690002  342.850006  355.940002
# 2025-02-14 00:00:00-05:00  360.619995  362.000000  347.500000  355.839996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
tesla = yf.Ticker("SPY")

# Get today's date in the required format (YYYY-MM-DD)
end_date = datetime.today().strftime('2025-02-18')

# Get historical market data from January 1, 2016, to today
tesla_data = tesla.history(start="2016-01-01", end=end_date)

# Display the data
print(tesla_data)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2016-01-04 00:00:00-05:00  171.918379  172.381419  170.289139  172.372849
# 2016-01-05 00:00:00-05:00  172.698723  173.127468  171.541117  172.664429
# 2016-01-06 00:00:00-05:00  170.074799  171.549685  169.440264  170.486404
# 2016-01-07 00:00:00-05:00  167.493798  169.303105  166.001758  166.396210
# 2016-01-08 00:00:00-05:00  167.373671  167.939618  164.278128  164.569672
# ...                               ...         ...         ...         ...
# 2025-02-10 00:00:00-05:00  604.030029  605.500000  602.739990  604.849976
# 2025-02-11 00:00:00-05:00  602.549988  605.859985  602.429993  605.309998
# 2025-02-12 00:00:00-05:00  599.200012  604.549988  598.510010  603.359985
# 2025-02-13 00:00:00-05:00  604.479980  609.940002  603.200012  609.729980
# 2025-02-14 00:00:00-05:00  609.940002  610.989990  609.070007  609.700012
#
# ...
